# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://[api_token]@github.com/Aysenursvs/CENG467-Text-to-SQL.git
# %cd CENG467-Text-to-SQL
# Out:
# Cloning into 'CENG467-Text-to-SQL'...
# remote: Enumerating objects: 157, done.
# remote: Counting objects: 100% (157/157), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 157 (delta 79), reused 127 (delta 50), pack-reused 0 (from 0)
# Receiving objects: 100% (157/157), 1004.23 KiB | 3.21 MiB/s, done.
# Resolving deltas: 100% (79/79), done.
# /content/CENG467-Text-to-SQL

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 19.1 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers==4.41.2 trl==0.8.6 peft==0.11.1 accelerate==0.31.0 bitsandbytes --upgrade
# Out:
# ...
#   Using cached bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# ...
# Using cached bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
# ...
#   Attempting uninstall: bitsandbytes
#     Found existing installation: bitsandbytes 0.43.1
#     Uninstalling bitsandbytes-0.43.1:
#       Successfully uninstalled bitsandbytes-0.43.1
# ...

# %%
from huggingface_hub import login
# Aldığınız token'ı buraya yapıştırın
login(token="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")

# %%
# Eğer veri setini GitHub'a pushlamadıysanız önce bunu çalıştırıp jsonl dosyasını oluşturun:
# !python src/data_prep.py

# %%
# !git pull

# %%
# Ve büyük an! Model eğitimini başlatıyoruz:
# !python src/train.py
# Out:
# 2026-06-02 09:13:37.913108: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# 🚀 Text-to-SQL Model Eğitimi (Instruction Tuning) Başlıyor!
# ...
#
# [1/5] Eğitim verisi yükleniyor: data/train_formatted.jsonl
#
# [2/5] Tokenizer ve Model (mistralai/Mistral-7B-v0.1) 4-bit olarak yükleniyor...
# Loading checkpoint shards:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# Loading checkpoint shards: 100% 2/2 [01:02<00:00, 31.32s/it]
# generation_config.json: 100% 116/116 [00:00<00:00, 598kB/s]
#
# ...

# %%
# Google Drive üzerinden Spider'ın orijinal veritabanı zip dosyasını indiriyoruz
# !pip install gdown
# !gdown --id 1_Oqj8Op5VCbrzZ2xXQ0YnZ0R1uYw4wEw -O spider.zip

# Zip'i çıkartıp içindeki 'database' klasörünü kendi data/ klasörümüze taşıyoruz
# !unzip -q spider.zip
# !mv spider/database data/database
# !rm -rf spider spider.zip
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1_Oqj8Op5VCbrzZ2xXQ0YnZ0R1uYw4wEw
#
# but Gdown can't. Please check connections and permissions.
# unzip:  cannot find or open spider.zip, spider.zip.zip or spider.zip.ZIP.
# mv: cannot stat 'spider/database': No such file or directory

# %%
import os
from google.colab import files

# Modeli zipliyoruz
os.system("zip -r lora_model.zip models/sql-mistral-lora")

# Bilgisayara indiriyoruz
files.download('lora_model.zip')
