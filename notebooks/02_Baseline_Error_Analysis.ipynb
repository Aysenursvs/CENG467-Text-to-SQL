# %%
import json
import pandas as pd

# evaluate.py'nin ürettiği sonuçları oku
with open('../results/baseline_results.json', 'r', encoding='utf-8') as f:
    results = json.load(f)

print("--- ZERO-SHOT HATALARI ---")
zs_errors = results.get("zero_shot_errors", [])
for err in zs_errors[:3]: # İlk 3 hatayı göster
    print(f"\nSoru: {err['question']}")
    print(f"Hedef SQL: {err['target_sql']}")
    print(f"Modelin Ürettiği SQL: {err['predicted_sql']}")
    print("-" * 40)
